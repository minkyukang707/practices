# %% [markdown]
# # 멕시코풍 프랜차이즈 chipotle의 주문 데이터
#
# chipotle.tsc : csv :셀의 구분
# tsv : 셀의 구분 \t(탭), sep='\t' 설정
#
# <step1 탐색> : 데이터의 기초 정보 살펴보기
# - chipotle 데이터셋의 기본 정보, chipotle 값으로 데이터 로드, pandas를 이용하여 읽기
# - chipotle 데이터셋의 행과 열 데이터
# - chipotle 데이터셋의 수치적 특징 파악

# %%
import pandas as pd

# %%
chipo = pd.read_csv('C:/pyy/chipotle.tsv', sep='\t')
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#행과 열의 값 출력
chipo.shape
# Out:
# (4622, 5)

# %%
#10건의 레코드 조회하기
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#chipo 컬럼명 조회하기
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#chipo index 조회하기
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#수치적 특징 파악하기
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
# order_id 주문번호이므로 숫자형 분석의 의미가 없다
# order_id 피처의 자료형을 문자열형으로 변경하기
chipo['order_id'] = chipo['order_id'].astype(str)
chipo.describe()
# Out:
#           quantity
# count  4622.000000
# mean      1.075725
# std       0.410186
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      15.000000

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   object
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 180.7+ KB

# %% [markdown]
# # 탐색의 시각화
#
# - item_name 종류 출력하기
# - 가장 많이 주문한 item
# - item 당 주문 개수 조회
# - 시각화 표시

# %%
#item_name 종류 및 갯수 출력하기
print(chipo['item_name'].unique())
print('종류 개수:',len(chipo['item_name'].unique()))
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %%
#item별 주문수량 조회하기
print(chipo['item_name'].value_counts())
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
#가장 많이 주문한 item 10개 출력하기
print(chipo['item_name'].value_counts()[:10])
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Chips                  211
# Steak Bowl             211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: item_name, dtype: int64

# %%
#item당 주문 개수 조회하기
order_count=chipo.groupby('item_name')['order_id'].count()
print(order_count)
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
#전체 주문의 갯수
print(chipo['order_id'].tail())
print(chipo['order_id'].unique())
# Out:
# 4617    1833
# 4618    1833
# 4619    1834
# 4620    1834
# 4621    1834
# Name: order_id, dtype: object
# ['1' '2' '3' ... '1832' '1833' '1834']

# %%
# 간단한 시각화
# item 주문 개수를 시각화로 출력하기
# 가장 많은 주문 10개의 데이터만 막드개르포 출력하기
# 정렬 
print(type(order_count))
order_count=order_counts.sort_values(ascending=False)[:10]
print(order_count)
# Out:
# <class 'pandas.core.series.Series'>
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Steak Burrito          368
# Canned Soft Drink      301
# Steak Bowl             211
# Chips                  211
# Bottled Water          162
# Chicken Soft Tacos     115
# Chicken Salad Bowl     110
# Name: order_id, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
item_name_list = order_count.index.tolist()
order_cnt = order_count.values.tolist()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize = (20,5))
ax = fig.add_subplot(1,1,1) # 1행 1열 1번째 그림판
ax.bar(item_name_list, order_cnt, align = 'center')
plt.xlabel('item Name')
plt.ylabel('ordered_item_count')
ax.set_xticklabels(item_name_list, rotation=45)
plt.title('Distribution of all ordered item')
plt.show()
# Out:
# <ipython-input-30-4087cd3bb7c5>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(item_name_list, rotation=45)

# %%
#문제: item당 총판매수량 분석하여 가장 주문 수량이 많은 item 10개를 막대그래프로 출력하기
item_qty = chipo.groupby('item_name')['quantity'].sum()
item_qty = item_qty.sort_values(ascending=False)[:10]
item_qty
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

# %%
item_name_list = item_qty.index.tolist()
sell_cnt = item_qty.values.tolist()
fig=plt.figure(figsize=(20,5))
ax=fig.add_subplot(1,1,1) #1행 1열 1번째 그림판
ax.bar(item_name_list,sell_cnt, align = 'center')
plt.xlabel('item Name')
plt.ylabel('selled_item_count')
ax.set_xticklabels(item_name_list, rotation=45)
plt.title('Distribution of all sell item')
plt.show()
# Out:
# <ipython-input-35-c495ab58960c>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(item_name_list, rotation=45)

# %%
#item_price 컬럼을 실수형 데이터로 변경하기
# chipo['item_price'].astype('float') # $ 표시때문에 실수변환불가
#lambda 방식
chipo['item_price']=chipo['item_price'].apply(lambda x:float(x[1:]))
chipo['item_price'].head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: float64

# %%
chipo.describe()
# Out:
#           quantity   item_price
# count  4622.000000  4622.000000
# mean      1.075725     7.464336
# std       0.410186     4.245557
# min       1.000000     1.090000
# 25%       1.000000     3.390000
# 50%       1.000000     8.750000
# 75%       1.000000     9.250000
# max      15.000000    44.250000

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   object
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 180.7+ KB

# %%
# 주문당 평균 주문금액 출력하기
'''
주문번호 : 주문금액 
example)
1 : 1
1 : 3 
2 : 1 
2 : 1 

주문금액합계: 6
주문건수: 2 
주문당 평균 주문금액: 3
'''
# Out:
# '\n주문번호 : 주문금액 \nexample)\n1 : 1\n1 : 3 \n2 : 1 \n2 : 1 \n\n주문금액합계: 6\n주문건수: 2 \n주문당 평균 주문금액: 3\n'

# %%
chipo.groupby('order_id')['item_price'].sum()
chipo.groupby('order_id')['item_price'].describe()
# Out:
#           count       mean       std    min      25%    50%     75%    max
# order_id
# 1           4.0   2.890000  0.577350   2.39   2.3900   2.89   3.390   3.39
# 10          2.0   6.600000  3.040559   4.45   5.5250   6.60   7.675   8.75
# 100         2.0   5.040000  5.586144   1.09   3.0650   5.04   7.015   8.99
# 1000        2.0  10.250000  1.414214   9.25   9.7500  10.25  10.750  11.25
# 1001        2.0   5.040000  5.586144   1.09   3.0650   5.04   7.015   8.99
# ...         ...        ...       ...    ...      ...    ...     ...    ...
# 995         3.0   8.316667  3.494758   4.45   6.8500   9.25  10.250  11.25
# 996         4.0  10.750000  1.354006   8.75  10.6250  11.25  11.375  11.75
# 997         1.0  22.500000       NaN  22.50  22.5000  22.50  22.500  22.50
# 998         2.0   5.440000  4.313351   2.39   3.9150   5.44   6.965   8.49
# 999         4.0   7.312500  3.216980   2.50   7.1875   8.75   8.875   9.25
#
# [1834 rows x 8 columns]

# %%
chipo.groupby('order_id')['item_price'].mean()
# Out:
# order_id
# 1        2.890000
# 10       6.600000
# 100      5.040000
# 1000    10.250000
# 1001     5.040000
#           ...
# 995      8.316667
# 996     10.750000
# 997     22.500000
# 998      5.440000
# 999      7.312500
# Name: item_price, Length: 1834, dtype: float64

# %%
#한번의 주문시 주문금액이 50달러 이상인 주문 ID를 출력하기

#주문별 합계금액
order_group_tot = chipo.groupby('order_id').sum()
order_group_tot
# Out:
#           quantity  item_price
# order_id
# 1                4       11.56
# 10               2       13.20
# 100              2       10.08
# 1000             2       20.50
# 1001             2       10.08
# ...            ...         ...
# 995              3       24.95
# 996              4       43.00
# 997              2       22.50
# 998              2       10.88
# 999              5       29.25
#
# [1834 rows x 2 columns]

# %%
#주문별 합계금액 >=50
results=order_group_tot[order_group_tot.item_price>=50]
results
# Out:
#           quantity  item_price
# order_id
# 1006             8       71.40
# 1051             7       59.35
# 1360             6       52.18
# 1443            35      160.74
# 1449            11       95.39
# 1454            10       85.24
# 1483            14      139.00
# 1559            16       82.44
# 1586             6       51.20
# 1660            19       70.25
# 1764             7       55.55
# 1786            20      114.30
# 1825             6       66.50
# 195              8       81.00
# 205             12      109.90
# 343              7       54.05
# 488              6       50.90
# 491             10      102.00
# 511             17      104.59
# 561             10       52.45
# 577             11       71.15
# 691             11      118.25
# 759             18       86.30
# 818              9       70.85
# 848              7       55.45
# 916              8       52.45
# 926             23      205.25
# 953              8       81.14

# %%
print(results.index.values) # ID 출력
# Out:
# ['1006' '1051' '1360' '1443' '1449' '1454' '1483' '1559' '1586' '1660'
#  '1764' '1786' '1825' '195' '205' '343' '488' '491' '511' '561' '577'
#  '691' '759' '818' '848' '916' '926' '953']

# %%
print(len(results.index.values)) # ID의 갯수
# Out:
# 28

# %%
#주문 ID에 해당하는 chipo 레코드 출력하기
chipo.loc[chipo['order_id'].isin(results.index.values)]
# Out:
#      order_id  quantity         item_name  \
# 448       195         1   Chicken Burrito
# 449       195         1      Chicken Bowl
# 450       195         1  Barbacoa Burrito
# 451       195         1   Chicken Burrito
# 452       195         1   Chicken Burrito
# ...       ...       ...               ...
# 4590     1825         1      Chicken Bowl
# 4591     1825         1      Chicken Bowl
# 4592     1825         1  Barbacoa Burrito
# 4593     1825         1     Carnitas Bowl
# 4594     1825         1     Barbacoa Bowl
#
#                                      choice_description  item_price
# 448   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...        8.75
# 449   [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 450   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.75
# 451   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...        8.75
# 452   [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       11.25
# ...

# %%
# 각 item의 단가를 조회하기
# 각 item별 금액이 가장 작은 금액 => 단가
# 수량이 2개인 가격조회 

item_two_price = chipo[chipo.quantity==2] # 수량 두개 
item_two_price[['quantity','item_name','item_price']]
item_one_price = chipo[chipo.quantity==1] # 수량 1개, 단가
item_one_price[['quantity','item_name','item_price']]
price_one_item=chipo.groupby('item_name').min()
price_one_item = price_one_item['item_price']
price_one_item # 단가 조회
# Out:
# item_name
# 6 Pack Soft Drink                        6.49
# Barbacoa Bowl                            8.69
# Barbacoa Burrito                         8.69
# Barbacoa Crispy Tacos                    8.99
# Barbacoa Salad Bowl                      9.39
# Barbacoa Soft Tacos                      8.99
# Bottled Water                            1.09
# Bowl                                     7.40
# Burrito                                  7.40
# Canned Soda                              1.09
# Canned Soft Drink                        1.25
# Carnitas Bowl                            8.99
# Carnitas Burrito                         8.69
# Carnitas Crispy Tacos                    8.99
# Carnitas Salad                           8.99
# Carnitas Salad Bowl                      9.39
# Carnitas Soft Tacos                      8.99
# Chicken Bowl                             8.19
# Chicken Burrito                          8.19
# Chicken Crispy Tacos                     8.49
# ...

# %%
#각 item단가의 분포를 히스토그램으로 표시하기 
plt.hist(price_one_item)
plt.ylabel('counts')
plt.title('Histogram of item price')
plt.show()

# %%
# 단가가 높은 아이템 10개를 출력하기
price_top10 = price_one_item.sort_values(ascending=False)[:10]
price_top10
# Out:
# item_name
# Steak Salad Bowl         9.39
# Barbacoa Salad Bowl      9.39
# Carnitas Salad Bowl      9.39
# Carnitas Soft Tacos      8.99
# Carnitas Crispy Tacos    8.99
# Steak Soft Tacos         8.99
# Carnitas Salad           8.99
# Carnitas Bowl            8.99
# Barbacoa Soft Tacos      8.99
# Barbacoa Crispy Tacos    8.99
# Name: item_price, dtype: float64

# %%
#주문당 가격이 비싼 상위 5건의 주문의 총수량을 출력
#주문당 가격의 합을 출력
#수량 부분 제외, item_price 부분만 선택 
chipo.groupby('order_id').sum()['item_price'].sort_values(ascending=False)[:5]
# Out:
# order_id
# 926     205.25
# 1443    160.74
# 1483    139.00
# 691     118.25
# 1786    114.30
# Name: item_price, dtype: float64

# %%
#by='item_pirce' : 정렬 기준이 되는 컬럼 설정
chipo.groupby('order_id').sum().sort_values(by='item_price',ascending=False)[:5]
# Out:
#           quantity  item_price
# order_id
# 926             23      205.25
# 1443            35      160.74
# 1483            14      139.00
# 691             11      118.25
# 1786            20      114.30

# %%
result1 = chipo.groupby('order_id').sum()
result1
# Out:
#           quantity  item_price
# order_id
# 1                4       11.56
# 10               2       13.20
# 100              2       10.08
# 1000             2       20.50
# 1001             2       10.08
# ...            ...         ...
# 995              3       24.95
# 996              4       43.00
# 997              2       22.50
# 998              2       10.88
# 999              5       29.25
#
# [1834 rows x 2 columns]

# %%
#정렬기준 추가
result2 = result1.sort_values(by='item_price', ascending= False)
result2
# Out:
#           quantity  item_price
# order_id
# 926             23      205.25
# 1443            35      160.74
# 1483            14      139.00
# 691             11      118.25
# 1786            20      114.30
# ...            ...         ...
# 1014             2       10.08
# 730              2       10.08
# 14               2       10.08
# 332              2       10.08
# 393              2       10.08
#
# [1834 rows x 2 columns]

# %%
# 주문 당 수량이 많은 상위 5건의 주문의 총수량과 금액을 출력하기 
chipo.groupby('order_id').sum().sort_values(by='quantity', ascending = False)[:10]
# Out:
#           quantity  item_price
# order_id
# 1443            35      160.74
# 926             23      205.25
# 1786            20      114.30
# 1660            19       70.25
# 759             18       86.30
# 511             17      104.59
# 1559            16       82.44
# 1483            14      139.00
# 205             12      109.90
# 691             11      118.25

# %%
# Veggie Salad Bowl이 몇번이나 주문되었는지 구하기 
chipo_salad = chipo[chipo['item_name']=='Veggie Salad Bowl']

# %%
chipo_salad['item_name'].head()
# Out:
# 186    Veggie Salad Bowl
# 295    Veggie Salad Bowl
# 455    Veggie Salad Bowl
# 496    Veggie Salad Bowl
# 960    Veggie Salad Bowl
# Name: item_name, dtype: object

# %%
chipo_salad.groupby('order_id').sum()
# Out:
#           quantity  item_price
# order_id
# 1066             1        8.75
# 128              1       11.25
# 1289             1       11.25
# 1321             1        8.75
# 1646             1       11.25
# 1677             1       11.25
# 1700             1       11.25
# 1805             1        8.75
# 1818             1        8.75
# 195              1       11.25
# 207              1       11.25
# 394              1        8.75
# 536              1        8.75
# 760              1       11.25
# 83               1       11.25
# 869              1       11.25
# 896              1        8.75
# 913              1        8.75

# %%
print(len(chipo_salad.groupby('order_id').sum()))
# Out:
# 18

# %%
print(chipo_salad.groupby('order_id').sum().shape[0])
# Out:
# 18

# %%
#한 주문 내에서 중복 집계된 item_name 제거
chipo_salad=chipo_salad.drop_duplicates(['item_name','order_id'])

# %%
print(chipo_salad)
# Out:
#      order_id  quantity          item_name  \
# 186        83         1  Veggie Salad Bowl
# 295       128         1  Veggie Salad Bowl
# 455       195         1  Veggie Salad Bowl
# 496       207         1  Veggie Salad Bowl
# 960       394         1  Veggie Salad Bowl
# 1316      536         1  Veggie Salad Bowl
# 1884      760         1  Veggie Salad Bowl
# 2156      869         1  Veggie Salad Bowl
# 2223      896         1  Veggie Salad Bowl
# 2269      913         1  Veggie Salad Bowl
# 2683     1066         1  Veggie Salad Bowl
# 3223     1289         1  Veggie Salad Bowl
# 3293     1321         1  Veggie Salad Bowl
# 4109     1646         1  Veggie Salad Bowl
# 4201     1677         1  Veggie Salad Bowl
# 4261     1700         1  Veggie Salad Bowl
# 4541     1805         1  Veggie Salad Bowl
# 4573     1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# 186   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# ...

# %%
print(len(chipo_salad))
# Out:
# 18
